# %%
import pandas as pd
import matplotlib.pyplot as plt
from sktime.forecasting.exp_smoothing import ExponentialSmoothing
from sktime.forecasting.ets import AutoETS
from sktime.split import temporal_train_test_split

import warnings

from src.config import get_config

warnings.filterwarnings("ignore")

# %%
config = get_config()

stations_timeseries = pd.read_csv(config.processed_data_path / 'stations_timeseries.csv', index_col=0, parse_dates=True)
# Set index frequency to hourly
stations_timeseries.index = pd.DatetimeIndex(stations_timeseries.index).to_period('H')
# Keep only column named 90
stations_timeseries = stations_timeseries[['90']]

# %%
# Split into train and test
train, test = temporal_train_test_split(stations_timeseries, test_size=0.2)

# %%
model = ExponentialSmoothing(sp=24*7, trend='add', seasonal='add')

model.fit(train)

pred = model.predict(fh=test.index).round(0)

# %%
both = pd.concat([test, pred], axis=1)
both.columns = ['Test', 'Prediction']
both.plot(figsize=(12, 8))
# Out:
# <Axes: >

# %%
model_auto = AutoETS(auto=True, sp=24*7, n_jobs=-1)

model_auto.fit(train)

pred_auto = model_auto.predict(fh=test.index).round(0)

# %%
both_auto = pd.concat([test, pred_auto], axis=1)
both_auto.columns = ['Test', 'Prediction']
both_auto.plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='timestamps'>

# %%
# Use last 24 hours as a predicton of the test set
pred_last_24 = stations_timeseries.shift(24).round(0)[-len(test):]

both_last_24 = pd.concat([test, pred_last_24], axis=1)
both_last_24.columns = ['Test', 'Prediction']
both_last_24.plot(figsize=(12, 8))
# Out:
# <Axes: xlabel='timestamps'>

# %%
pred_last_24['2022-11-02 00:00:00':'2022-11-02 23:00:00']
# Out:
#                     90
# timestamps
# 2022-11-02 00:00  18.0
# 2022-11-02 01:00  17.0
# 2022-11-02 02:00  20.0
# 2022-11-02 03:00  14.0
# 2022-11-02 04:00  10.0
# 2022-11-02 05:00   9.0
# 2022-11-02 06:00   9.0
# 2022-11-02 07:00   9.0
# 2022-11-02 08:00   8.0
# 2022-11-02 09:00   7.0
# 2022-11-02 10:00   7.0
# 2022-11-02 11:00   7.0
# 2022-11-02 12:00   7.0
# 2022-11-02 13:00  11.0
# 2022-11-02 14:00  12.0
# 2022-11-02 15:00  17.0
# 2022-11-02 18:00  13.0
# 2022-11-02 19:00  11.0
# 2022-11-02 20:00  12.0
# 2022-11-02 21:00  14.0
# 2022-11-02 22:00  16.0
# 2022-11-02 23:00  17.0

# %%
test['2022-11-01 00:00:00':'2022-11-01 23:00:00']
# Out:
#                   90
# timestamps
# 2022-11-01 00:00  18
# 2022-11-01 01:00  17
# 2022-11-01 02:00  20
# 2022-11-01 03:00  14
# 2022-11-01 04:00  10
# 2022-11-01 05:00   9
# 2022-11-01 06:00   9
# 2022-11-01 07:00   9
# 2022-11-01 08:00   8
# 2022-11-01 09:00   7
# 2022-11-01 10:00   7
# 2022-11-01 11:00   7
# 2022-11-01 12:00   7
# 2022-11-01 13:00  11
# 2022-11-01 14:00  12
# 2022-11-01 15:00  17
# 2022-11-01 16:00  13
# 2022-11-01 17:00  11
# 2022-11-01 18:00  12
# 2022-11-01 19:00  14
# 2022-11-01 20:00  16
# 2022-11-01 21:00  17
# 2022-11-01 22:00  15
# 2022-11-01 23:00  14

# %%
import numpy as np

def predict_hours(time_series, n, end_date):
    """
    Predicts hours based on the mean of the previous n days and continues predicting until the end_date.

    Parameters:
    - time_series: A pandas Series with datetime index containing the time series data.
    - n: Number of previous days to consider for the mean.
    - end_date: End date until which predictions will be made.

    Returns:
    - A pandas Series with the predicted hours.
    """
    predictions = pd.Series(index=pd.date_range(start=time_series.index[0].to_timestamp(), end=end_date.to_timestamp(), freq='H'))

    for date in predictions.index:
        if date in time_series.index:
            # If the date is in the original time series, use the actual value
            predictions[date] = time_series[date]
        else:
            # Calculate the mean of the previous n days and predict the hour
            previous_n_days = time_series.loc[date - pd.DateOffset(days=n):date - pd.DateOffset(days=1)]
            predictions[date] = pd.mean(previous_n_days)

    return predictions

pred_mean_7 = predict_hours(train, 7, test.index[-1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Timestamp('2022-01-01 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 28
#      24             predictions[date] = np.mean(previous_n_days)
#      26     return predictions
# ---> 28 pred_mean_7 = predict_hours(train, 7, test.index[-1])
#
# Cell In[49], line 20, in predict_hours(time_series, n, end_date)
#      17 for date in predictions.index:
#      18     if date in time_series.index:
#      19         # If the date is in the original time series, use the actual value
# ---> 20         predictions[date] = time_series[date]
#      21     else:
#      22         # Calculate the mean of the previous n days and predict the hour
#      23         previous_n_days = time_series.loc[date - pd.DateOffset(days=n):date - pd.DateOffset(days=1)]
#
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: Timestamp('2022-01-01 00:00:00')

# %%
test.index[-1].to_timestamp()
# Out:
# Timestamp('2022-12-31 23:00:00')

# %%
def get_n_days_before(df, n, date):
    """
    Returns the date n days before the given date.

    Parameters:
    - date: Date to consider.
    - n: Number of days before the given date.

    Returns:
    - A pandas Timestamp with the date n days before the given date.
    """
    print(date - pd.DateOffset(days=n))
    print(date - pd.DateOffset(days=1))

    return df[date - pd.DateOffset(days=n):date - pd.DateOffset(days=1):24]

def predict_hours(time_series, n, end_date):
    """
    Predicts hours based on the mean of the previous n days and continues predicting until the end_date.

    Parameters:
    - time_series: A pandas Series with datetime index containing the time series data.
    - n: Number of previous days to consider for the mean.
    - end_date: End date until which predictions will be made.

    Returns:
    - A pandas Series with the predicted hours.
    """
    predictions = time_series.copy(deep=True)
    # Convert dataframe to series
    if isinstance(predictions, pd.DataFrame):
        predictions = predictions.squeeze()
    
    date_range = pd.date_range(start=time_series.index[-1].to_timestamp() + pd.DateOffset(hours=1), end=end_date.to_timestamp(), freq='H')

    # Extend the time series with the new dates
    predictions = pd.concat([predictions, pd.Series(index=date_range)])
    print(predictions)
    for date in date_range:
        print(date)
        # Calculate the mean of the previous n days and predict the hour
        print(type(predictions.index[0]))
        previous_n_days = get_n_days_before(predictions, n, date)
        predictions[date] = previous_n_days.mean()

    return predictions

pred_mean_7 = predict_hours(train, 2, test.index[-1])

# Join test and predictions by index
both_mean_7 = pd.concat([test, pred_mean_7], axis=1)
both_mean_7.columns = ['Test', 'Prediction']
both_mean_7.plot(figsize=(12, 8))
# Out:
# 2022-01-01 00:00       19.0
# 2022-01-01 01:00       19.0
# 2022-01-01 02:00       19.0
# 2022-01-01 03:00       18.0
# 2022-01-01 04:00       18.0
#                        ...
# 2022-12-31 19:00:00     NaN
# 2022-12-31 20:00:00     NaN
# 2022-12-31 21:00:00     NaN
# 2022-12-31 22:00:00     NaN
# 2022-12-31 23:00:00     NaN
# Length: 8762, dtype: float64
# 2022-10-19 04:00:00
# <class 'pandas._libs.tslibs.period.Period'>
# 2022-10-17 04:00:00
# 2022-10-18 04:00:00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:219, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:227, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:119, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: Timestamp('2022-10-17 04:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[149], line 48
#      44         predictions[date] = previous_n_days.mean()
#      46     return predictions
# ---> 48 pred_mean_7 = predict_hours(train, 2, test.index[-1])
#      50 # Join test and predictions by index
#      51 both_mean_7 = pd.concat([test, pred_mean_7], axis=1)
#
# Cell In[149], line 43, in predict_hours(time_series, n, end_date)
#      41     # Calculate the mean of the previous n days and predict the hour
#      42     print(type(predictions.index[0]))
# ---> 43     previous_n_days = get_n_days_before(predictions, n, date)
#      44     predictions[date] = previous_n_days.mean()
#      46 return predictions
#
# Cell In[149], line 15, in get_n_days_before(df, n, date)
#      12 print(date - pd.DateOffset(days=n))
#      13 print(date - pd.DateOffset(days=1))
# ---> 15 return df[date - pd.DateOffset(days=n):date - pd.DateOffset(days=1):24]
#
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\series.py:1065, in Series.__getitem__(self, key)
#    1061             return self._get_values_tuple(key)
#    1063 if isinstance(key, slice):
#    1064     # Do slice check before somewhat-costly is_bool_indexer
# -> 1065     return self._getitem_slice(key)
#    1067 if com.is_bool_indexer(key):
#    1068     key = check_bool_indexer(self.index, key)
#
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\generic.py:4284, in NDFrame._getitem_slice(self, key)
#    4279 """
#    4280 __getitem__ for the case where the key is a slice object.
#    4281 """
#    4282 # _convert_slice_indexer to determine if this slice is positional
#    4283 #  or label based, and if the latter, convert to positional
# -> 4284 slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    4285 if isinstance(slobj, np.ndarray):
#    4286     # reachable with DatetimeIndex
#    4287     indexer = lib.maybe_indices_to_slice(
#    4288         slobj.astype(np.intp, copy=False), len(self)
#    4289     )
#
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\indexes\base.py:4286, in Index._convert_slice_indexer(self, key, kind)
#    4284     indexer = key
#    4285 else:
# -> 4286     indexer = self.slice_indexer(start, stop, step)
#    4288 return indexer
#
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\indexes\base.py:6602, in Index.slice_indexer(self, start, end, step)
#    6558 def slice_indexer(
#    6559     self,
#    6560     start: Hashable | None = None,
#    6561     end: Hashable | None = None,
#    6562     step: int | None = None,
#    6563 ) -> slice:
#    6564     """
#    6565     Compute the slice indexer for input labels and step.
#    6566
#    (...)
#    6600     slice(1, 3, None)
#    6601     """
# -> 6602     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6604     # return a slice
#    6605     if not is_scalar(start_slice):
#
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\indexes\base.py:6819, in Index.slice_locs(self, start, end, step)
#    6817 start_slice = None
#    6818 if start is not None:
# -> 6819     start_slice = self.get_slice_bound(start, "left")
#    6820 if start_slice is None:
#    6821     start_slice = 0
#
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\indexes\base.py:6744, in Index.get_slice_bound(self, label, side)
#    6741         return self._searchsorted_monotonic(label, side)
#    6742     except ValueError:
#    6743         # raise the original KeyError
# -> 6744         raise err
#    6746 if isinstance(slc, np.ndarray):
#    6747     # get_loc may return a boolean array, which
#    6748     # is OK as long as they are representable by a slice.
#    6749     assert is_bool_dtype(slc.dtype)
#
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\indexes\base.py:6738, in Index.get_slice_bound(self, label, side)
#    6736 # we need to look up the label
#    6737 try:
# -> 6738     slc = self.get_loc(label)
#    6739 except KeyError as err:
#    6740     try:
#
# File c:\Users\alvar\AppData\Local\pypoetry\Cache\virtualenvs\src-KiDfFX-I-py3.10\lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: Timestamp('2022-10-17 04:00:00')
